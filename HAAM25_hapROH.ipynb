# %% [markdown]
# # Vignette of Pypi-Package hapROH: Calling and visualizing ROH
# This notebook contains an example application of hapROH: We will identify ROH in a target Eigenstrat dataset from a recent publication (Skourtanioti et al., 2023).
# You will learn how to run hapROH on chromosomes of signle individuals, and sets of individuals, and how to post-process multiple output files into one summary datafile (including meta data). We will explore the most useful plotting functions, and how to estimate Ne and contamination from ROH.

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Arial'

import os as os
import sys as sys
import multiprocessing as mp

print(f"CPU Count: {mp.cpu_count()}")
# Out:
# CPU Count: 14

# %% [markdown]
# ### Get reference data
#
# Normally you cat download the reference data from `https://www.dropbox.com/s/0qhjgo1npeih0bw/1000g1240khdf5.taz.gz?dl=0`

# %%
#### We will run the download command at the command line:

#!wget https://www.dropbox.com/s/0qhjgo1npeih0bw/1000g1240khdf5.taz.gz?dl=0

# %% [markdown]
# ### Let's set the path to our dataset

# %%
import sys
### Fill in your own path here!
path = "/vol/volume/haproh/HAAM25_hapROH/"  # The Path to Package Midway Cluster
os.chdir(path)  # Set the right Path (in line with Atom default)
print(f"Set path to: {os.getcwd()}") # Show the current working directory. Should be HAPSBURG/Notebooks/ParallelRuns
# Out:
# Set path to: /vol/volume/haproh/HAAM25_hapROH

# %% [markdown]
# ### Let's have a look into the dataset with poseidon-trident

# %%
# !echo "Hello from Bash" ### exclamation mark means we are using bash

# !ls /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1/

# !trident summarise -d /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1
# Out:
# Hello from Bash
# 2023_Skourtanioti_Aegean.bed  2023_Skourtanioti_Aegean.fam    POSEIDON.yml
# 2023_Skourtanioti_Aegean.bib  2023_Skourtanioti_Aegean.janno
# 2023_Skourtanioti_Aegean.bim  CHANGELOG.md
# trident v1.6.2.1 for poseidon v2.5.0, v2.6.0, v2.7.0, v2.7.1
# https://poseidon-framework.github.io
#
# [Info]    Checking base directories...
# [Info]    Searching POSEIDON.yml files...
# [Info]    1 found
# [Info]    Checking Poseidon versions...
# [Info]    Initializing packages...
# [Info]    Packages loaded: 1
# [Info]    Note that only the latest versions of packages are included in the summary
# .--------------------.--------------------------------------------------------------.
# |      Summary       |                            Value                             |
# :====================:==============================================================:
# | Nr Samples         | 103                                                          |
# | Samples            | AID001, AID002, AID007, AID008, AID009, AID010, AID012, AID… |
# | Nr Primary Groups  | 26                                                           |
# | Primary Groups     | Chania_LBA: 26, HgCharalambos_EMBA: 22, Aposelemis_N: 6, Ai… |
# | Nr Publications    | 1                                                            |
# | Publications       | SkourtaniotiNatEcoEvo2023                                    |
# | Nr Countries       | 1                                                            |
# | Countries          | Greece: 103                                                  |
# | Mean age BC/AD     | -1768 ± 1014                                                 |
# | Dating type        | contextual: 63, C14: 40                                      |
# | Sex distribution   | M: 60, F: 43                                                 |
# | MT haplogroups     | n/a: 48, H: 4, HV+16311: 4, H4a1: 3, HV1a'b'c: 2, I5a: 2, J… |
# | Y haplogroups      | n/a: 46, J2a1a1a2: 10, J2a: 6, J2b2a1: 4, R1b1a1b: 4, G2a: … |
# | % endogenous DNA   | no values                                                    |
# | Nr of SNPs         | 434451 ± 287811                                              |
# | Coverage on target | 0.35 ± 0.23                                                  |
# | Library type       | ss: 53, ds: 35, mixed: 15                                    |
# | UDG treatment      | minus: 53, half: 35, mixed: 15                               |
# '--------------------'--------------------------------------------------------------'

# %% [markdown]
# **Let's explore the columns of the annotation file**

# %%
# !head -1 /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1/2023_Skourtanioti_Aegean.janno | sed s/'\t'/'\n'/g
# Out:
# Poseidon_ID
# Genetic_Sex
# Group_Name
# Alternative_Group_Name
# Alternative_IDs
# Relation_To
# Relation_Degree
# Relation_Type
# Relation_Note
# Collection_ID
# Country
# Location
# Site
# Latitude
# Longitude
# Date_Type
# Date_C14_Labnr
# Date_C14_Uncal_BP
# Date_C14_Uncal_BP_Err
# Date_BC_AD_Start
# Date_BC_AD_Median
# Date_BC_AD_Stop
# Date_Note
# MT_Haplogroup
# Y_Haplogroup
# Source_Tissue
# Nr_Libraries
# Capture_Type
# UDG
# Library_Built
# Genotype_Ploidy
# Nr_SNPs
# Coverage_on_Target_SNPs
# Primary_Contact
# Publication

# %% [markdown]
# ##### **Essential meta-information for hapROH is `Poseidon_ID` (`'id'`), `Group_name` (`'clst'`), and `Date_BC_AD_Median` (`'age'`); also `Genetic_Sex`, `Nr_SNPs`, `Latitude`, `Longitude` and `Location`.**

# %% [markdown]
# ### Step1: convert from plink to eigenstrat format

# %%
# !trident genoconvert \
  --bedFile /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1/2023_Skourtanioti_Aegean.bed \
  --famFile /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1/2023_Skourtanioti_Aegean.fam \
  --bimFile /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1/2023_Skourtanioti_Aegean.bim \
  -o /vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen \
  --outFormat EIGENSTRAT

# %%
##Quick look into the *ind file
ind_frame = pd.read_csv("/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean.ind", sep='\t', header=None)
ind_frame

# %% [markdown]
# ### Step 2: Call ROH (on specific individuals)
# #### Example run of whole individual (all chromosomes) with output to logfile

# %%
from hapsburg.PackagesSupport.hapsburg_run import hapsb_ind  ##import function

# %%
hapsb_ind(iid="AID008", chs=range(1,23),
          path_targets='/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean', 
          h5_path1000g='/vol/volume/haproh/1000g1240khdf5/all1240/chr',  ## reference panel (1000G); per chromosome - hdf5 format
          meta_path_ref='/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv', ### metainfo for reference panel
          folder_out='./indExample', ## Name of directory where you want to store your results
          e_model="haploid", p_model="Eigenstrat", output=False, save=True,
          processes=4, ## will run 4 chromosomes in parallel
          
          post_model='Standard', 
          save_fp=False, n_ref=2504, exclude_pops=[], 
          roh_in=1, roh_out=20, roh_jump=300, e_rate=0.01, e_rate_ref=0.0, 
          cutoff_post=0.999, max_gap=0, 
          random_allele=True, readcounts=False, # Whether to pick one of two alleles at Target Individual at random; whether to return Readcounts
          logfile=False, combine=True, file_result='_roh_full.csv')  ## logfile=False will output log but won't save it
# Out:
# Using Rescaled HMM.Using Rescaled HMM.Using Rescaled HMM.Using Rescaled HMM.
#
#
#
# Loaded Pre Processing Model: EigenstratLoaded Pre Processing Model: EigenstratLoaded Pre Processing Model: Eigenstrat
#
# Loaded Pre Processing Model: Eigenstrat
#
# Loading Individual: AID008Loading Individual: AID008Loading Individual: AID008Loading Individual: AID008
#
#
#
#
# Loaded 77652 variants
# Loaded 59890 variants
#
# Loaded 89147 variants
# Loaded 2504 individualsLoaded 2504 individuals
#
#
# Loaded 2504 individualsHDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr7.hdf5
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr3.hdf5
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr1.hdf5
# Loaded 69399 variants
#
#
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr5.hdf5
# Eigenstrat packed: FalseEigenstrat packed: FalseEigenstrat packed: FalseEigenstrat packed: False
#
#
#
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 59890
# Nr of Matching Refs: 59890 / 59890
# Ref/Alt Matching: 59836 / 59890
# Flipped Ref/Alt Matching: 0
# Together: 59836 / 59890
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
#
# Intersection on Positions: 69399
# Nr of Matching Refs: 69399 / 69399
# Ref/Alt Matching: 69354 / 69399
# Flipped Ref/Alt Matching: 0
# Together: 69354 / 69399
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
#
# Intersection on Positions: 89147
# Nr of Matching Refs: 89147 / 89147
# Ref/Alt Matching: 89082 / 89147
# Flipped Ref/Alt Matching: 0
# Together: 89082 / 89147
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
#
# Intersection on Positions: 77652
# Nr of Matching Refs: 77652 / 77652
# Ref/Alt Matching: 77601 / 77652
# Flipped Ref/Alt Matching: 0
# Together: 77601 / 77652
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 39748 / 59836
# Fraction SNPs covered: 0.6643
# Reduced to markers with data: 61556 / 89082
# Fraction SNPs covered: 0.6910
# Reduced to markers with data: 46177 / 69354
# Fraction SNPs covered: 0.6658
# Reduced to markers with data: 52078 / 77601
# Fraction SNPs covered: 0.6711
# Exctraction of hdf5 done. Subsetting...!
# Exctraction of hdf5 done. Subsetting...!
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr7/
# Shuffling phase of target...
# Exctraction of hdf5 done. Subsetting...!
# Successfully loaded Data from: ./indExample/AID008/chr7/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	7
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.8715 Morgan
# Gaps bigger than 0.1 cM: 253
# Maximum Gap: 0.8484 cM
# Upper Gap Cutoff: 5.0000 cM
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr5/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr5/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	5
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0004 Morgan
# Maximum Genetic Map: 2.0409 Morgan
# Gaps bigger than 0.1 cM: 280
# Maximum Gap: 1.0498 cM
# Upper Gap Cutoff: 5.0000 cM
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr3/
# Shuffling phase of target...
# Successfully saved target individual data to: ./indExample/AID008/chr1/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr3/
# Successfully loaded Data from: ./indExample/AID008/chr1/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	3
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 2.2326 Morgan
# Gaps bigger than 0.1 cM: 278
# Maximum Gap: 0.2681 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	1
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0202 Morgan
# Maximum Genetic Map: 2.8627 Morgan
# Gaps bigger than 0.1 cM: 336
# Maximum Gap: 2.9727 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 39748)
# Loaded Observations:
# (2, 39748)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 46177)
# Loaded Observations:
# (2, 46177)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 52078)
# Loaded Observations:
# (2, 52078)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 61556)
# Loaded Observations:
# (2, 61556)
# Memory Usage at end of HMM:
# Memory Usage: 2154.938368 mB
# Total Log likelihood: -15510.463
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr7/.
# Successfully loaded for PP. from ./indExample/AID008/chr7/
# Fraction Markers in ROH: 0.2110
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr7/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 61133 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr8.hdf5
# Eigenstrat packed: False
# Memory Usage at end of HMM:
# Memory Usage: 2444.681216 mB
# Total Log likelihood: -16643.242
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr5/.
# Successfully loaded for PP. from ./indExample/AID008/chr5/
# Fraction Markers in ROH: 0.2765
# Called n=1 ROH Blocks > 4.0 cM
# Longest Block: 4.22 cM
# Successfully saved to ./indExample/AID008/chr5/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 75870 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr6.hdf5
# Eigenstrat packed: False
# Memory Usage at end of HMM:
# Memory Usage: 2712.887296 mB
# Total Log likelihood: -18703.272
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr3/.
# Successfully loaded for PP. from ./indExample/AID008/chr3/
# Fraction Markers in ROH: 0.2873
# Called n=1 ROH Blocks > 4.0 cM
# Longest Block: 9.24 cM
# Successfully saved to ./indExample/AID008/chr3/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 68759 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr4.hdf5
# Eigenstrat packed: False
# Memory Usage at end of HMM:
# Memory Usage: 3140.36224 mB
# Total Log likelihood: -23020.964
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr1/.
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
# Successfully loaded for PP. from ./indExample/AID008/chr1/
# Fraction Markers in ROH: 0.2222
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr1/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 94239 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr2.hdf5
# Eigenstrat packed: False
#
# Intersection on Positions: 61133
# Nr of Matching Refs: 61133 / 61133
# Ref/Alt Matching: 61091 / 61133
# Flipped Ref/Alt Matching: 0
# Together: 61091 / 61133
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 75870
# Nr of Matching Refs: 75870 / 75870
# Ref/Alt Matching: 75816 / 75870
# Flipped Ref/Alt Matching: 0
# Together: 75816 / 75870
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 68759
# Nr of Matching Refs: 68759 / 68759
# Ref/Alt Matching: 68720 / 68759
# Flipped Ref/Alt Matching: 0
# Together: 68720 / 68759
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 94239
# Nr of Matching Refs: 94239 / 94239
# Ref/Alt Matching: 94173 / 94239
# Flipped Ref/Alt Matching: 0
# Together: 94173 / 94239
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 41439 / 61091
# Fraction SNPs covered: 0.6783
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr8/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr8/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	8
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.6800 Morgan
# Gaps bigger than 0.1 cM: 174
# Maximum Gap: 3.3395 cM
# Upper Gap Cutoff: 5.0000 cM
# Reduced to markers with data: 50695 / 75816
# Fraction SNPs covered: 0.6687
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 41439)
# Loaded Observations:
# (2, 41439)
# Reduced to markers with data: 43717 / 68720
# Fraction SNPs covered: 0.6362
# Exctraction of hdf5 done. Subsetting...!
# Exctraction of hdf5 done. Subsetting...!
# Reduced to markers with data: 63172 / 94173
# Fraction SNPs covered: 0.6708
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr6/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr6/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	6
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0035 Morgan
# Maximum Genetic Map: 1.9203 Morgan
# Gaps bigger than 0.1 cM: 209
# Maximum Gap: 0.5066 cM
# Upper Gap Cutoff: 5.0000 cM
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr4/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr4/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	4
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0034 Morgan
# Maximum Genetic Map: 2.1454 Morgan
# Gaps bigger than 0.1 cM: 280
# Maximum Gap: 2.0440 cM
# Upper Gap Cutoff: 5.0000 cM
# Exctraction of hdf5 done. Subsetting...!
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 50695)
# Loaded Observations:
# (2, 50695)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 43717)
# Loaded Observations:
# (2, 43717)
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr2/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr2/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	2
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0001 Morgan
# Maximum Genetic Map: 2.6883 Morgan
# Gaps bigger than 0.1 cM: 303
# Maximum Gap: 2.9097 cM
# Upper Gap Cutoff: 5.0000 cM
# Memory Usage at end of HMM:
# Memory Usage: 2206.916608 mB
# Total Log likelihood: -14881.212
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr8/.
# Successfully loaded for PP. from ./indExample/AID008/chr8/
# Fraction Markers in ROH: 0.3148
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr8/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 50668 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr9.hdf5
# Eigenstrat packed: False
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 63172)
# Loaded Observations:
# (2, 63172)
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
# Memory Usage at end of HMM:
# Memory Usage: 2314.113024 mB
# Total Log likelihood: -16452.236
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr4/.
# Successfully loaded for PP. from ./indExample/AID008/chr4/
# Fraction Markers in ROH: 0.2284
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr4/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 54833 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr11.hdf5
# Eigenstrat packed: False
#
# Intersection on Positions: 50668
# Nr of Matching Refs: 50668 / 50668
# Ref/Alt Matching: 50629 / 50668
# Flipped Ref/Alt Matching: 0
# Together: 50629 / 50668
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Memory Usage at end of HMM:
# Memory Usage: 2762.457088 mB
# Total Log likelihood: -15724.777
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr6/.
# Successfully loaded for PP. from ./indExample/AID008/chr6/
# Fraction Markers in ROH: 0.3983
# Called n=2 ROH Blocks > 4.0 cM
# Longest Block: 37.18 cM
# Successfully saved to ./indExample/AID008/chr6/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 39018 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr13.hdf5
# Eigenstrat packed: False
# Memory Usage at end of HMM:
# Memory Usage: 3188.248576 mB
# Total Log likelihood: -23174.103
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr2/.
# Successfully loaded for PP. from ./indExample/AID008/chr2/
# Fraction Markers in ROH: 0.2616
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr2/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 34429 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr15.hdf5
# Eigenstrat packed: False
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 54833
# Nr of Matching Refs: 54833 / 54833
# Ref/Alt Matching: 54796 / 54833
# Flipped Ref/Alt Matching: 0
# Together: 54796 / 54833
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 39018
# Nr of Matching Refs: 39018 / 39018
# Ref/Alt Matching: 38994 / 39018
# Flipped Ref/Alt Matching: 0
# Together: 38994 / 39018
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 34429
# Nr of Matching Refs: 34429 / 34429
# Ref/Alt Matching: 34407 / 34429
# Flipped Ref/Alt Matching: 0
# Together: 34407 / 34429
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 34565 / 50629
# Fraction SNPs covered: 0.6827
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr9/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr9/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	9
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0016 Morgan
# Maximum Genetic Map: 1.6630 Morgan
# Gaps bigger than 0.1 cM: 231
# Maximum Gap: 2.3088 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 34565)
# Loaded Observations:
# (2, 34565)
# Reduced to markers with data: 37373 / 54796
# Fraction SNPs covered: 0.6820
# Exctraction of hdf5 done. Subsetting...!
# Reduced to markers with data: 25335 / 38994
# Fraction SNPs covered: 0.6497
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr11/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr11/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	11
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.5822 Morgan
# Gaps bigger than 0.1 cM: 206
# Maximum Gap: 0.5679 cM
# Upper Gap Cutoff: 5.0000 cM
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr13/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr13/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	13
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0021 Morgan
# Maximum Genetic Map: 1.2570 Morgan
# Gaps bigger than 0.1 cM: 179
# Maximum Gap: 1.2216 cM
# Upper Gap Cutoff: 5.0000 cM
# Memory Usage at end of HMM:
# Memory Usage: 1900.212224 mB
# Total Log likelihood: -13123.327
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr9/.
# Successfully loaded for PP. from ./indExample/AID008/chr9/
# Fraction Markers in ROH: 0.2064
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr9/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 58804 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr10.hdf5
# Eigenstrat packed: False
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 25335)
# Loaded Observations:
# (2, 25335)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 37373)
# Loaded Observations:
# (2, 37373)
# Reduced to markers with data: 23769 / 34407
# Fraction SNPs covered: 0.6908
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr15/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr15/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	15
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.4134 Morgan
# Gaps bigger than 0.1 cM: 165
# Maximum Gap: 13.7349 cM
# Upper Gap Cutoff: 5.0000 cM
# Memory Usage at end of HMM:
# Memory Usage: 1484.345344 mB
# Total Log likelihood: -9510.682
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr13/.
# Successfully loaded for PP. from ./indExample/AID008/chr13/
# Fraction Markers in ROH: 0.2224
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr13/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 36301 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr14.hdf5
# Eigenstrat packed: False
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 23769)
# Loaded Observations:
# (2, 23769)
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 58804
# Nr of Matching Refs: 58804 / 58804
# Ref/Alt Matching: 58763 / 58804
# Flipped Ref/Alt Matching: 0
# Together: 58763 / 58804
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Memory Usage at end of HMM:
# Memory Usage: 2030.309376 mB
# Total Log likelihood: -13817.227
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr11/.
# Successfully loaded for PP. from ./indExample/AID008/chr11/
# Fraction Markers in ROH: 0.2367
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr11/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 53911 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr12.hdf5
# Eigenstrat packed: False
# Memory Usage at end of HMM:
# Memory Usage: 1415.028736 mB
# Total Log likelihood: -8789.109
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr15/.
# Successfully loaded for PP. from ./indExample/AID008/chr15/
# Fraction Markers in ROH: 0.2652
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr15/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 34402 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr16.hdf5
# Eigenstrat packed: False
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 36301
# Nr of Matching Refs: 36301 / 36301
# Ref/Alt Matching: 36280 / 36301
# Flipped Ref/Alt Matching: 0
# Together: 36280 / 36301
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 53911
# Nr of Matching Refs: 53911 / 53911
# Ref/Alt Matching: 53884 / 53911
# Flipped Ref/Alt Matching: 0
# Together: 53884 / 53911
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 34402
# Nr of Matching Refs: 34402 / 34402
# Ref/Alt Matching: 34375 / 34402
# Flipped Ref/Alt Matching: 0
# Together: 34375 / 34402
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 40471 / 58763
# Fraction SNPs covered: 0.6887
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr10/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr10/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	10
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0001 Morgan
# Maximum Genetic Map: 1.8092 Morgan
# Gaps bigger than 0.1 cM: 217
# Maximum Gap: 2.0340 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 40471)
# Loaded Observations:
# (2, 40471)
# Reduced to markers with data: 24462 / 36280
# Fraction SNPs covered: 0.6743
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr14/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr14/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	14
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0184 Morgan
# Maximum Genetic Map: 1.2020 Morgan
# Gaps bigger than 0.1 cM: 152
# Maximum Gap: 3.3147 cM
# Upper Gap Cutoff: 5.0000 cM
# Reduced to markers with data: 36306 / 53884
# Fraction SNPs covered: 0.6738
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 24462)
# Loaded Observations:
# (2, 24462)
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr12/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr12/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	12
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0017 Morgan
# Maximum Genetic Map: 1.7468 Morgan
# Gaps bigger than 0.1 cM: 230
# Maximum Gap: 0.8015 cM
# Upper Gap Cutoff: 5.0000 cM
# Reduced to markers with data: 24541 / 34375
# Fraction SNPs covered: 0.7139
# Exctraction of hdf5 done. Subsetting...!
# Memory Usage at end of HMM:
# Memory Usage: 1447.051264 mB
# Total Log likelihood: -8157.916
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr14/.
# Successfully loaded for PP. from ./indExample/AID008/chr14/
# Fraction Markers in ROH: 0.3283
# Called n=1 ROH Blocks > 4.0 cM
# Longest Block: 22.01 cM
# Successfully saved to ./indExample/AID008/chr14/roh.csv
# Extraction of 5008 Haplotypes complete
# Using Rescaled HMM.
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 29314 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr17.hdf5
# Eigenstrat packed: False
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 36306)
# Loaded Observations:
# (2, 36306)
# Successfully saved target individual data to: ./indExample/AID008/chr16/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr16/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	16
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: -0.0000 Morgan
# Maximum Genetic Map: 1.3403 Morgan
# Gaps bigger than 0.1 cM: 183
# Maximum Gap: 0.8458 cM
# Upper Gap Cutoff: 5.0000 cM
# Memory Usage at end of HMM:
# Memory Usage: 2167.492608 mB
# Total Log likelihood: -15320.235
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr10/.
# Successfully loaded for PP. from ./indExample/AID008/chr10/
# Fraction Markers in ROH: 0.2132
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr10/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 18460 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr19.hdf5
# Eigenstrat packed: False
# Loaded Transition and Emission Matrix:
#
# (3, 3)(5009, 24541)
# Loaded Observations:
# (2, 24541)
# Memory Usage at end of HMM:
# Memory Usage: 1985.302528 mB
# Total Log likelihood: -13732.632
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr12/.
# Successfully loaded for PP. from ./indExample/AID008/chr12/
# Fraction Markers in ROH: 0.2175
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr12/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 16038 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr21.hdf5
# Eigenstrat packed: False
# Memory Usage at end of HMM:
# Memory Usage: 1453.051904 mB
# Total Log likelihood: -9003.876
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr16/.
# Successfully loaded for PP. from ./indExample/AID008/chr16/
# Fraction Markers in ROH: 0.2778
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr16/roh.csv
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 29314
# Nr of Matching Refs: 29314 / 29314
# Ref/Alt Matching: 29292 / 29314
# Flipped Ref/Alt Matching: 0
# Together: 29292 / 29314
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 18460
# Nr of Matching Refs: 18460 / 18460
# Ref/Alt Matching: 18441 / 18460
# Flipped Ref/Alt Matching: 0
# Together: 18441 / 18460
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 16038
# Nr of Matching Refs: 16038 / 16038
# Ref/Alt Matching: 16031 / 16038
# Flipped Ref/Alt Matching: 0
# Together: 16031 / 16038
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 21008 / 29292
# Fraction SNPs covered: 0.7172
# Exctraction of hdf5 done. Subsetting...!
# Reduced to markers with data: 13255 / 18441
# Fraction SNPs covered: 0.7188
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr17/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr17/
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	17
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0002 MorganSuccessfully saved target individual data to: ./indExample/AID008/chr19/
#
# Maximum Genetic Map: 1.2846 MorganShuffling phase of target...
#
#
# Maximum Gap: 1.2341 cMGaps bigger than 0.1 cM: 174
# Upper Gap Cutoff: 5.0000 cM
# Successfully loaded Data from: ./indExample/AID008/chr19/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	19
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.0773 Morgan
# Gaps bigger than 0.1 cM: 172
# Maximum Gap: 0.5964 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 13255)
# Loaded Observations:
# (2, 13255)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 21008)
# Loaded Observations:
# (2, 21008)
# Memory Usage at end of HMM:
# Memory Usage: 877.268992 mB
# Total Log likelihood: -5459.219
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr19/.
# Successfully loaded for PP. from ./indExample/AID008/chr19/
# Fraction Markers in ROH: 0.1639
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr19/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 29078 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr20.hdf5
# Eigenstrat packed: False
# Reduced to markers with data: 10671 / 16031
# Fraction SNPs covered: 0.6656
# Memory Usage at end of HMM:
# Memory Usage: 1295.48288 mB
# Total Log likelihood: -6819.991
# Finished Calculation State Posteriors
# Exctraction of hdf5 done. Subsetting...!
# Saved Zero State Posterior to folder ./indExample/AID008/chr17/.
# Successfully loaded for PP. from ./indExample/AID008/chr17/
# Fraction Markers in ROH: 0.3960
# Called n=1 ROH Blocks > 4.0 cM
# Longest Block: 21.83 cM
# Successfully saved to ./indExample/AID008/chr17/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 33917 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr18.hdf5
# Eigenstrat packed: False
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr21/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr21/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	21
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0087 Morgan
# Maximum Genetic Map: 0.6277 Morgan
# Gaps bigger than 0.1 cM: 101
# Maximum Gap: 0.5852 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 10671)
# Loaded Observations:
# (2, 10671)
# Memory Usage at end of HMM:
# Memory Usage: 779.358208 mB
# Total Log likelihood: -4128.303
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr21/.
# Successfully loaded for PP. from ./indExample/AID008/chr21/
# Fraction Markers in ROH: 0.2030
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr21/roh.csv
# Using Rescaled HMM.
# Loaded Pre Processing Model: Eigenstrat
# Loading Individual: AID008
#
# Loaded 15802 variants
# Loaded 2504 individuals
# HDF5 loaded from /vol/volume/haproh/1000g1240khdf5/all1240/chr22.hdf5
# Eigenstrat packed: False
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 29078
# Nr of Matching Refs: 29078 / 29078
# Ref/Alt Matching: 29053 / 29078
# Flipped Ref/Alt Matching: 0
# Together: 29053 / 29078
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 33917
# Nr of Matching Refs: 33917 / 33917
# Ref/Alt Matching: 33902 / 33917
# Flipped Ref/Alt Matching: 0
# Together: 33902 / 33917
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# 3 Eigenstrat Files with 103 Individuals and 1233013 SNPs
#
# Intersection on Positions: 15802
# Nr of Matching Refs: 15802 / 15802
# Ref/Alt Matching: 15793 / 15802
# Flipped Ref/Alt Matching: 0
# Together: 15793 / 15802
# 2504 / 2504 Individuals included in Reference
# Extracting up to 2504 Individuals
# Reduced to markers with data: 20901 / 29053
# Fraction SNPs covered: 0.7194
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr20/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr20/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	20
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0000 Morgan
# Maximum Genetic Map: 1.0821 Morgan
# Gaps bigger than 0.1 cM: 154
# Maximum Gap: 0.4744 cM
# Upper Gap Cutoff: 5.0000 cM
# Reduced to markers with data: 22491 / 33902
# Fraction SNPs covered: 0.6634
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 20901)
# Loaded Observations:
# (2, 20901)
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr18/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr18/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
# Reduced to markers with data: 11811 / 15793
# Parameters in hapsb_chrom:
#
# Fraction SNPs covered: 0.7479
# iid	AID008
# ch	18
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0025 Morgan
# Maximum Genetic Map: 1.1771 Morgan
# Gaps bigger than 0.1 cM: 169
# Maximum Gap: 0.4763 cM
# Upper Gap Cutoff: 5.0000 cM
# Exctraction of hdf5 done. Subsetting...!
# Extraction of 5008 Haplotypes complete
# Flipping Ref/Alt Alleles in target for 0 SNPs...
# Successfully saved target individual data to: ./indExample/AID008/chr22/
# Shuffling phase of target...
# Successfully loaded Data from: ./indExample/AID008/chr22/
# Loaded Emission Model: haploid
# Loaded Transition Model: model
# Loaded Post Processing Model: Standard
#
# Parameters in hapsb_chrom:
# iid	AID008
# ch	22
# save	True
# save_fp	False
# n_ref	2504
# diploid_ref	True
# exclude_pops	[]
# e_model	haploid
# p_model	Eigenstrat
# readcounts	False
# random_allele	True
# downsample	False
# post_model	Standard
# path_targets	/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean
# h5_path1000g	/vol/volume/haproh/1000g1240khdf5/all1240/chr
# meta_path_ref	/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# folder_out	./indExample
# prefix_out
# c	0.0
# conPop	['CEU']
# roh_in	1
# roh_out	20
# roh_jump	300
# e_rate	0.01
# e_rate_ref	0.0
# max_gap	0
# roh_min_l_initial	0.02
# roh_min_l_final	0.04
# min_len1	0.02
# min_len2	0.04
# cutoff_post	0.999
# logfile	False
#
#
# Minimum Genetic Map: 0.0178 Morgan
# Maximum Genetic Map: 0.7408 Morgan
# Gaps bigger than 0.1 cM: 94
# Maximum Gap: 1.6153 cM
# Upper Gap Cutoff: 5.0000 cM
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 22491)
# Loaded Observations:
# (2, 22491)
# Loaded Transition and Emission Matrix:
# (3, 3)
# (5009, 11811)
# Loaded Observations:
# (2, 11811)
# Memory Usage at end of HMM:
# Memory Usage: 1292.476416 mB
# Total Log likelihood: -7780.734
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr20/.
# Successfully loaded for PP. from ./indExample/AID008/chr20/
# Fraction Markers in ROH: 0.2549
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr20/roh.csv
# Memory Usage at end of HMM:
# Memory Usage: 827.16672 mB
# Total Log likelihood: -4451.577
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr22/.
# Successfully loaded for PP. from ./indExample/AID008/chr22/
# Fraction Markers in ROH: 0.2223
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr22/roh.csv
# Memory Usage at end of HMM:
# Memory Usage: 1364.39808 mB
# Total Log likelihood: -8409.019
# Finished Calculation State Posteriors
# Saved Zero State Posterior to folder ./indExample/AID008/chr18/.
# Successfully loaded for PP. from ./indExample/AID008/chr18/
# Fraction Markers in ROH: 0.2314
# Called n=0 ROH Blocks > 4.0 cM
# Longest Block: nan cM
# Successfully saved to ./indExample/AID008/chr18/roh.csv
# /home/ubuntu/bin/miniconda3/envs/haproh/lib/python3.12/site-packages/hapsburg/PackagesSupport/parallel_runs/helper_functions.py:98: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   full_df = pd.concat(full_df_vec)
#    Start    End    StartM      EndM length   lengthM     iid  ch  \
# 0   4689   7037  0.279616  0.372063   2348  0.092447  AID008   3
# 0  10520  12001  0.565448  0.607642   1481  0.042194  AID008   5
# 0  30591  31805  1.048921  1.102692   1214  0.053771  AID008   6
# 1  42305  49737  1.507634  1.879433   7432  0.371799  AID008   6
# 0    368   3723  0.065563  0.285677   3355  0.220114  AID008  14
# 0  16495  19806  0.954418  1.172732   3311  0.218314  AID008  17
#
#   StartPosGRCh37 EndPosGRCh37
# 0       11736290     18929861
# 0       38119545     44392142
# 0      100300738    106292430
# 1      147549297    168478917
# 0       21432455     33829320
# 0       67519542     76849664

# %% [markdown]
# ### Output files

# %%
# !ls ./indExample
# Out:
# AID008	AID008_roh_full.csv

# %%
# !ls ./indExample/AID008
# Out:
# chr1   chr11  chr13  chr15  chr17  chr19  chr20  chr22	chr4  chr6  chr8
# chr10  chr12  chr14  chr16  chr18  chr2   chr21  chr3	chr5  chr7  chr9

# %%
# !ls ./indExample/AID008/chr17
# Out:
# hap.csv  hmm_run_log.txt  map.csv  pos.csv  posterior0.csv  roh.csv

# %% [markdown]
# ### Step 3.1: Let's visualize ROH for AID008!

# %%
from hapsburg.figures.plot_individual_roh import plot_roh_individual ## "Karyotype'

# %%
plot_roh_individual(iid="AID008", folder="./indExample/", 
                    prefix_out="", min_cm=4, snp_cm=50, savepath="", plot_bad=False) ### emply string at savepath -> not saved
                                            # at least 50 1240k within 1 cM to call roh
                                            # plot_bad=TRUE -> plot low density areas of the genome

# %% [markdown]
# #### Step 3.2: Visualize posterior probability of ROH (QC)

# %%
from hapsburg.figures.plot_posterior import plot_posterior_cm

# %%
plot_posterior_cm(folder = "./indExample/AID008/chr17/", savepath="", 
                  empirical=True, m=1, cm_lim=[], groundtruth = False, min_cm=1,
                  readcount=False, figsize=(10,4), title="AID008, Chromosome 17")
# Out:
# Successfully loaded Data from: ./indExample/AID008/chr17/

# %% [markdown]
# #### Zoom-in
# We now change the `cm_lim` parameter, which allows user to zoom in

# %%
plot_posterior_cm(folder = "./indExample/AID008/chr17/", savepath="",
                  empirical=True, m=1, cm_lim=[90, 120], groundtruth = False, min_cm=1,
                  readcount=False, figsize=(16,4), title="AID008, Chromosome 17, zoom")
# Out:
# Successfully loaded Data from: ./indExample/AID008/chr17/

# %% [markdown]
# --> Lower blue 'line' is composed of dots each one representing SNP positions from 1240k panel in that chromosome

# %% [markdown]
# ### Great! Now let's scale the analysis to multiple individuals!
# ## Step 4: all ROH on multiple individuals in a loop

# %% [markdown]
# #### Let's run ROH for the individuals with the group label "HgCharalambos_EMBA". There are 22 in total and many of them have sufficient coverage for hapROH.
#
# We need to subset 1. for this group and 2. for Nr_SNPs > 400,000

# %%
Aegean_df = pd.read_csv("/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean-1.0.1/2023_Skourtanioti_Aegean.janno", sep='\t', header=0) 

subset_df = (
    Aegean_df
    .pipe(lambda df: df[(df["Group_Name"] == "HgCharalambos_EMBA") & (df["Nr_SNPs"] > 400000)])
    .pipe(lambda df: df[["Poseidon_ID", "Group_Name", "Nr_SNPs", "Date_BC_AD_Median", "Genetic_Sex"]])  # select columns
)

subset_df
# Out:
#    Poseidon_ID          Group_Name  Nr_SNPs  Date_BC_AD_Median Genetic_Sex
# 21      HGC001  HgCharalambos_EMBA  1040566                NaN           M
# 23      HGC003  HgCharalambos_EMBA   511956                NaN           F
# 24      HGC005  HgCharalambos_EMBA   516744                NaN           M
# 25      HGC006  HgCharalambos_EMBA  1058362                NaN           M
# 26      HGC008  HgCharalambos_EMBA   747989                NaN           F
# 27      HGC009  HgCharalambos_EMBA   779131                NaN           M
# 28      HGC010  HgCharalambos_EMBA   514088            -2100.0           M
# 29      HGC011  HgCharalambos_EMBA   893737            -2100.0           F
# 32      HGC017  HgCharalambos_EMBA   910790            -2100.0           M
# 33      HGC018  HgCharalambos_EMBA   716850            -2100.0           M
# 34      HGC020  HgCharalambos_EMBA   604284            -2100.0           F
# 35      HGC024  HgCharalambos_EMBA   634929            -2100.0           M
# 36      HGC025  HgCharalambos_EMBA   569775            -2100.0           M
# 40      HGC032  HgCharalambos_EMBA   480812            -2100.0           M

# %% [markdown]
# #### Extract list of ids from dataframe

# %%
# %%time ##measures execution time of the entire code cell

iids = subset_df['Poseidon_ID'].to_list()

for iid in iids:
    print(f"Doing Individual: {iid}")
    hapsb_ind(iid=iid, chs=range(1,23), processes=4, 
          path_targets='/vol/volume/packages-poseidon/2023_Skourtanioti_Aegean_eigen/2023_Skourtanioti_Aegean', 
          h5_path1000g='/vol/volume/haproh/1000g1240khdf5/all1240/chr',  ## reference panel (1000G); per chromosome - hdf5 format
          meta_path_ref='/vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv', ### metainfo for reference panel
          folder_out='./HGC', prefix_out='', 
          e_model="haploid", p_model="Eigenstrat", n_ref=2504,
          random_allele=True, readcounts=False, output=False)

# %% [markdown]
# ### Postprocess Results into one results.csv (copying in Meta Data)
# Take indivdiual output .csvs and combine into one big results .csv
# Merging of output gaps, and ROH>x cM happens here

# %%
from hapsburg.PackagesSupport.pp_individual_roh_csvs import pp_individual_roh

# %% [markdown]
# ### Create Example Meta File
# This file will yield the meta data file (some plotting functions use it),
# which is then merged into the results when combining individuals
#
# We can use our table after subsetting the janno file, but we need to **change the column names as follows:**

# %%
subset_df.rename(columns={"Poseidon_ID": "iid", "Group_Name": "clst", "Date_BC_AD_Median": "age"}, inplace=True)

subset_df.to_csv("./HGC/meta_blank.csv", 
          sep=",", index=False)

# %% [markdown]
# ## Combine into output File
# Combines meta file, individual ROH output files
# into a summary table, contaiining ROH information for each individual

# %%
# %%time
### Postprocess the elected Individuals from above and combine into one results .csv

df1 = pp_individual_roh(iids, meta_path="./HGC/meta_blank.csv", 
                        base_folder="./HGC",
                        save_path="./HGC/combined_roh05.csv", 
                        output=False, min_cm=[4, 8, 12, 20], snp_cm=50, 
                        gap=0.5, min_len1=2.0, min_len2=4.0)

df1

# %% [markdown]
# ## Plot summary over multiple Individuals
#
# First plot only expectations, for instance as a legend.
# You could choose which expectations in the method parameters (plot_bars.py file)

# %%
from hapsburg.figures.plot_bars import plot_legend_only, plot_panel_row, prepare_dfs_plot

# %%
plot_legend_only(savepath="", figsize=[4,3.5])

# %% [markdown]
# #### **IMPORTANT!** The expectation for every scenario of parental relatedness is an **average**. As recombination is a stochastic process, there is a variance on ROH distribution within each scenario.

# %% [markdown]
# ## Now let's plot our dataset.
#
# -prepare_dfs_plot prepared from the combined csv (splitting it up into a list of pandas dataframes, these dataframes will be plot in groups - you could also manually produce these lists (check `plot_bars.py`)
#
# -plot_panel_row then plots these data frames
#
# In this simple usecase, the individuals analyzed above are plotted, together with a legend to the right.

# %%
df1 = pd.read_csv("./HGC/combined_roh05.csv", sep='\t')
#df1["clst"] = df1["Genetic_Sex"]   ## if you want to plot for another variable
plot_dfs, cols = prepare_dfs_plot(df1, cms=[4, 8, 12, 20])

# for all parameters check ~/bin/miniconda3/envs/haproh/lib/python3.12/site-packages/hapsburg/figures/plot_bars.py
plot_panel_row(plot_dfs, wspace=0., r_title=0, leg_pos=-1, title_col="clst", titles = [],
               ylim=[0,350], figsize=(8,3.5), savepath="") ### make sure you set the ylim very high in the beginning

# %% [markdown]
# At least five individuals show close parental relatedness! Their ROH distribution approximates that of first cousins, but other parental scenarios of similar degree can be possible. Also a few individuals have short and middle roh, but not long (>20cM).

# %% [markdown]
# ### Do Histogram of the Length Distribution and theoretical expectations

# %%
from hapsburg.figures.plot_individual_roh import plot_pde_individual

# %%
plot_pde_individual(iid="HGC005", min_cm=4, bw_cm=4, 
                    kde_plot=False, plotlim=[4, 100], prefix_out="",
                    savepath="", folder="./HGC/", title="HGC005",
                    
                    comm_ancs=[4,4,4,2], ms=[6,5,4,3], labels=["First Cousins", "Aunt/Nephew", "Full Siblings", "Parent/Offpsring"],
                    cs=["red", "green", "orange", "gray"], leg_loc="upper right")

# %%
### Which is the most likely degree of parental relatedness?

# %%
plot_pde_individual(iid = ["HGC005", "HGC006", "HGC017", "HGC020", "HGC024"], min_cm=4, bw_cm=4, 
                    kde_plot=False, plotlim=[4, 100], prefix_out="",
                    comm_ancs=[4,4,4,2], ms=[6,5,4,3], labels=["First Cousins", "Aunt/Nephew", "Full Siblings", "Parent/Offpsring"],
                    cs=["red", "green", "orange", "gray"], title="", leg_loc="upper right",
                    savepath="", folder="./HGC/")
# Out:
# Loaded ROH of 5 individuals. Plotting their sum...

# %% [markdown]
# ## Ne size estimation

# %% [markdown]
# Now we will learn how to estimate pop size from specific length bins of ROH. The model assumes a panmictic population, so think of this estimate as the size of ancestors' pool at the time depth of the origin of the ROH that you are fitting

# %%
from hapsburg.PackagesSupport.fit_ne import MLE_ROH_Ne, load_roh_vec

# %%
#df1 = pd.read_csv("./HGC/combined_roh05.csv", sep='\t')
df2 = df1[df1["sum_roh>20"]<50] # Reomve inbred individuals
iids = df2["iid"].values ## create list of all iids

print(f"Loaded {len(iids)} IIDs")
# Out:
# Loaded 10 IIDs

# %% [markdown]
# ### Load the data for the MLE analysis

# %%
roh_vec = load_roh_vec(iids=iids, base_path = "/vol/volume/haproh/HAAM25_hapROH/HGC", suffix = "_roh_full.csv")

# %% [markdown]
# ### Use ML to fit Ne
# With roh_vec loaded, we can fit the Ne. We use a class implemented in hapROH which returns a pandas dataframe with most likely estimate and two colums for the lower and upper bound of the 95% CI intervall.
#
# Note that the ratio of Ne to census size can be 0.1-0.3 depending on demography (skew of reproductive success, how many generations alive etc)
#
# **By default the estimates are reported for 2Ne!**

# %%
# %%time
output = True
min_len = 4 # Min ROH length in cM to fit 
max_len = 20 # Max ROH length in cM to fit

mle = MLE_ROH_Ne(start_params = 1000, endog = roh_vec, min_len = min_len, max_len = max_len, chr_lgts = [], ## Lengths of Chromosomes to fit (in cM). If len 0, use defaulr for 1240k
                 error_model = False, output = False)
fit = mle.fit_ll_profile()

mle.summary/2
# Out:
# CPU times: user 740 ms, sys: 5.27 ms, total: 745 ms
# Wall time: 743 ms
#           coef  std err        0.025        0.975    n
# 0  2106.660872      NaN  1460.277756  3189.883404  5.0

# %% [markdown]
# ## Estimating Contamination from ROH blocks
#
# We will now try the hapCon_ROH module to jointly estimate ROH and contamination rates
#
# **Application:** Female individuals with ROH (like HGC011)
#
# **Input:** Bam file
#
# We will also need `BamTable` or `samtools` and per-chromosome `.bed` files to create the `readcounts` per 1240k position.

# %%
# %%time
import os
os.chdir("/vol/volume/haproh/HAAM25_hapROH/haproh_cont")
os.getcwd()

## with samtools
# !for ch in {1..22}; do ~/bin/miniconda3/envs/nf-core-eager/bin/samtools mpileup --positions /vol/volume/haproh/1000g1240khdf5/1240kChr$ch.bed -r $ch -q 30 -Q 30 -o ./mpileup/HGC011.chr$ch.mpileup /vol/volume/haproh/data/HGC011.dslib_rmdup.q30.bam; done

## with BamTable (if installed)
#!for ch in {1..22}; do BamTable -f /vol/volume/haproh/1000g1240khdf5/1240kChr$ch.bed -b -A  /vol/volume/haproh/data/HGC011.dslib_rmdup.q30.bam > ./HGC011.chr$ch.BamTable; done
# Out:
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# [mpileup] 1 samples in 1 input files
# CPU times: user 175 ms, sys: 72.5 ms, total: 247 ms
# Wall time: 10.5 s

# %%
# !hapCon_ROH -h

# %%
# %%time
# !hapCon_ROH --mpileup ./mpileup -i HGC011 -p 8 --prefix iter_ROH -r /vol/volume/haproh/1000g1240khdf5/all1240/chr --meta /vol/volume/haproh/1000g1240khdf5/all1240/meta_df_all.csv
# Out:
# saving hdf5 files in /vol/volume/haproh/HAAM25_hapROH/haproh_cont/hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as HGC011 in /vol/volume/haproh/HAAM25_hapROH/haproh_cont/hdf5/HGC011.chr8.hdf5
# saving sample as HGC011 in /vol/volume/haproh/HAAM25_hapROH/haproh_cont/hdf5/HGC011.chr7.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as HGC011 in /vol/volume/haproh/HAAM25_hapROH/haproh_cont/hdf5/HGC011.chr4.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as HGC011 in /vol/volume/haproh/HAAM25_hapROH/haproh_cont/hdf5/HGC011.chr5.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites
# saving sample as HGC011 in /vol/volume/haproh/HAAM25_hapROH/haproh_cont/hdf5/HGC011.chr6.hdf5
# exclude 0 sites outside the specified region
# exclude 0 non-SNP sites

# %% [markdown]
# What is the estimated contamination of our sample?

# %% [markdown]
# ### Let's have a look at how (low) contamination looks like in the ROH blocks
# Also, we can identify False Positive ROH Segments

# %% [markdown]
# First, let's find where are the ROH identified for HGC011

# %%
# !cat ./hapRoh_iter/HGC011/chr*/roh.csv
# Out:
# /vol/volume/haproh/HAAM25_hapROH/haproh_cont
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# 7922,11023,0.35043201,0.46971399,3101,0.11928198000000001,HGC011,11,20161913,30774280
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# 204,1732,0.016089,0.101142,1528,0.08505299999999999,HGC011,12,672372,4081766
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# 20023,22036,1.04194498,1.16272295,2013,0.12077797000000001,HGC011,17,71546716,76555985
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# 4884,6249,0.363098,0.425623,1365,0.062525,HGC011,18,12048608,21849020
# 15984,17850,0.72007602,0.78687602,1866,0.06679999999999997,HGC011,18,52058435,57173844
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# 3516,5345,0.220882,0.30903801,1829,0.08815600999999998,HGC011,7,11778424,16996956
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37
# Start,End,StartM,EndM,length,lengthM,iid,ch,StartPosGRCh37,EndPosGRCh37

# %%
from hapsburg.figures.plot_posterior import plot_posterior_cm

plot_posterior_cm(folder = "./hapRoh_iter/HGC011/chr11/", savepath = "", empirical = True, m=1, cm_lim = [30, 55], groundtruth = False, min_cm=1, readcount=True, figsize = (10,4), 
                  title = "HGC011 -  contam. test - Chr11")
# Out:
# Successfully loaded Data from: ./hapRoh_iter/HGC011/chr11/

# %% [markdown]
# A few regions outside the called ROH might appear to be in ROH state, but they are very short (<4cM) and cannot be confidently called as real ROH. That's why in contamination estimates we only use ROH blocks > 5 cM.
